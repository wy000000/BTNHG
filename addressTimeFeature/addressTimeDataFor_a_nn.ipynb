# %%
import set_parent_dir
print("start import")
import time
time1 = time.time()
import sys
import os
# 获取当前文件所在目录的父目录
# parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
# sys.path.append(parent_dir)
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeFeature.addressTimeFeatureClass import addressTimeFeatureClass
from EarlyStoppingClass import EarlyStoppingClass
from resultAnalysisClass import resultAnalysisClass
from ExtendedNNModule import ExtendedNNModule
from addressTimeDataClass import addressTimeDataClass
import torch
import torch.nn as nn
import datetime
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import importlib
time2 = time.time()
print("import used time: ", time2 - time1)
print(f"当前时间: {time.strftime('%m-%d %H:%M:%S', time.localtime())}")
# Out:
# start import
# import used time:  7.660508632659912
# 当前时间: 01-12 23:42:07

# %%
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
importlib.reload(sys.modules['BTNHGV2ParameterClass'])
importlib.reload(sys.modules['addressTimeDataClass'])
importlib.reload(sys.modules['addressTimeFeatureClass'])
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
addressTimeDataCls=addressTimeDataClass()

print(f"当前时间：{time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())}")
# Out:
# start read addressTimeData
# 读取耗时：0时0分0秒, addressTime_data_df.shape=(110935, 8)
# start process address time data
# 已完成20000行，进度18.03%
# 已完成40001行，进度36.06%
# 已完成60002行，进度54.09%
# 已完成80003行，进度72.12%
# 已完成100004行，进度90.15%
# 更新差异特征
# 时间特性处理完成。address_dict长度= 15218
# 时间特性处理耗时：0时0分6秒
# start build self.addressTimeFeature_dataSet
# 已完成2000行，进度13.14%
# 已完成4001行，进度26.29%
# 已完成6002行，进度39.44%
# 已完成8003行，进度52.59%
# 已完成10004行，进度65.74%
# 已完成12005行，进度78.89%
# 已完成14006行，进度92.04%
# build self.addressTimeFeature_dataSet used time: 0时0分6秒
# 当前时间：2026-01-12 23:58:24

# %%
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
from ExtendedNNModule import ExtendedNNModule
from EarlyStoppingClass import EarlyStoppingClass
from DataSetModelTrainerTesterClass import DataSetModelTrainerTesterClass
from simple2DCNNClass import simple2DCNNClass
from resultAnalysisClass import resultAnalysisClass

importlib.reload(sys.modules['BTNHGV2ParameterClass'])
importlib.reload(sys.modules['addressTimeDataClass'])
importlib.reload(sys.modules['addressTimeFeatureClass'])
importlib.reload(sys.modules['ExtendedNNModule'])
importlib.reload(sys.modules['EarlyStoppingClass'])
importlib.reload(sys.modules['DataSetModelTrainerTesterClass'])
importlib.reload(sys.modules['simple2DCNNClass'])
importlib.reload(sys.modules['resultAnalysisClass'])

from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
from ExtendedNNModule import ExtendedNNModule
from EarlyStoppingClass import EarlyStoppingClass
from DataSetModelTrainerTesterClass import DataSetModelTrainerTesterClass
from simple2DCNNClass import simple2DCNNClass
from resultAnalysisClass import resultAnalysisClass

model=simple2DCNNClass(addressTimeFeature_dataSet=addressTimeDataCls.addressTimeFeature_dataSet)

TrainerTesterCls=DataSetModelTrainerTesterClass(model=model, addressTimeDataCls=addressTimeDataCls)
# resultAnalyCls=TrainerTesterCls.train_test()
resultAnalyCls=TrainerTesterCls.kFold_train_test()

print(f"当前时间: {time.strftime('%m-%d %H:%M:%S', time.localtime())}")
# Out:
# using device: cuda
# start kFold_train_test
# start build KFold indices
# build KFold dataLoaders used time: 0时0分0秒
# Processing fold 1/5
# 开始训练模型，使用设备: cuda
# simple2DCNNClass | Epoch   1 | loss: 2.7635 | accuracy: 2.3493 | best Loss: 2.7635 | patience:  0 | used time: 00:00:22
# Training completed, epoch : 1, loss: 2.7635, accuracy: 2.3493, used time: 00:00:22
# restore best model in epoch 1, best loss: 2.7635
# Training completes
# start test
# 测试用时: 1.8647563457489014
# Evaluation metrics are computed.
# fold 1/5 is completed.
# Processing fold 2/5
# 开始训练模型，使用设备: cuda
# simple2DCNNClass | Epoch   1 | loss: 2.6747 | accuracy: 6.6782 | best Loss: 2.6747 | patience:  0 | used time: 00:00:22
# Training completed, epoch : 1, loss: 2.6747, accuracy: 6.6782, used time: 00:00:22
# restore best model in epoch 1, best loss: 2.6747
# Training completes
# start test
# 测试用时: 1.8358147144317627
# Evaluation metrics are computed.
# fold 2/5 is completed.
# Processing fold 3/5
# 开始训练模型，使用设备: cuda
# simple2DCNNClass | Epoch   1 | loss: 2.7050 | accuracy: 4.3946 | best Loss: 2.7050 | patience:  0 | used time: 00:00:22
# Training completed, epoch : 1, loss: 2.7050, accuracy: 4.3946, used time: 00:00:22
# restore best model in epoch 1, best loss: 2.7050
# Training completes
# start test
# 测试用时: 1.8347411155700684
# Evaluation metrics are computed.
# fold 3/5 is completed.
# Processing fold 4/5
# 开始训练模型，使用设备: cuda
# simple2DCNNClass | Epoch   1 | loss: 2.5764 | accuracy: 17.4127 | best Loss: 2.5764 | patience:  0 | used time: 00:00:23
# Training completed, epoch : 1, loss: 2.5764, accuracy: 17.4127, used time: 00:00:23
# restore best model in epoch 1, best loss: 2.5764
# Training completes
# start test
# 测试用时: 1.9642348289489746
# Evaluation metrics are computed.
# fold 4/5 is completed.
# Processing fold 5/5
# 开始训练模型，使用设备: cuda
# simple2DCNNClass | Epoch   1 | loss: 2.7993 | accuracy: 2.9158 | best Loss: 2.7993 | patience:  0 | used time: 00:00:22
# Training completed, epoch : 1, loss: 2.7993, accuracy: 2.9158, used time: 00:00:22
# restore best model in epoch 1, best loss: 2.7993
# Training completes
# start test
# 测试用时: 1.912334680557251
# Evaluation metrics are computed.
# fold 5/5 is completed.
# kFold_train_test用时: 168.28191876411438
# 当前时间: 01-13 00:01:16

# %%
# from resultAnalysisClass import resultAnalysisClass
# importlib.reload(sys.modules['resultAnalysisClass'])
# from resultAnalysisClass import resultAnalysisClass

# resultAnalyCls.save()
resultAnalyCls.save_kFold()
print(f"当前时间: {time.strftime('%m-%d %H:%M:%S', time.localtime())}")
# Out:
# methodFolderPath=D:\BTNHG\BTNHGV2\result\simple2DCNNClass-kFold-2026.01.13 00.01.46-acc 0.0660
# BTNHGV2ParameterClass.txt已保存
# extendedAttributes.txt已保存
# 195 kFold_evaluationMetrics.xlsx 已保存
# model.state_dict.pt已保存
# 当前时间: 01-13 00:01:46

# %%
resultAnalyCls.showEvaluationMetrics()
resultAnalyCls.showExtendedAttributes()
resultAnalyCls.plot_true_pred_counts()
resultAnalyCls.plot_confusion_matrix()
# Out:
# accuracy: 0.02366086099244167
# training_time: None
# avg_confidence: 0.10825779289007187
# balanced_accuracy: 0.07164767747589833
# precision_macro: 0.07310231023102311
# recall_macro: 0.07164767747589833
# f1_macro: 0.003707706289590204
# precision_weighted: 0.10767784961210548
# recall_weighted: 0.02366086099244167
# f1_weighted: 0.0017236585867156091
# roc_auc_macro: 0.5098899222522004
# pr_auc_macro: 0.08389942740459268
# cohen_kappa: -6.537493465264e-05
# mcc: -0.0007355446791596479
# {
#     "modelName": "simple2DCNNClass",
#     "training_time": null,
#     "accuracy": 0.02366086099244167,
#     "end_epoch_loss": "Training completed, epoch : 1, loss: 2.7993, accuracy: 2.9158",
#     "best_epoch_loss": "best model in epoch 1, best loss: 2.7993",
#     "evaluationMetrics": {
#         "accuracy": 0.02366086099244167,
#         "training_time": null,
#         "avg_confidence": 0.10825779289007187,
#         "balanced_accuracy": 0.07164767747589833,
#         "precision_macro": 0.07310231023102311,
#         "recall_macro": 0.07164767747589833,
#         "f1_macro": 0.003707706289590204,
#         "precision_weighted": 0.10767784961210548,
#         "recall_weighted": 0.02366086099244167,
#         "f1_weighted": 0.0017236585867156091,
#         "roc_auc_macro": 0.5098899222522004,
#         "pr_auc_macro": 0.08389942740459268,
#         "cohen_kappa": -6.537493465264e-05,
#         "mcc": -0.0007355446791596479
#     },
#     "env_info": {
#         "System": "Windows",
#         "Architecture": "X86_64",
#         "CPU": "Intel(R) Core(TM) i7-6700HQ CPU @ 2.60GHz",
#         "Cores": 4,
#         "memory_total_GB": 15.89,
#         "gpu_available": true,
#         "gpu_count": 1,
#         "GPU 0": "NVIDIA GeForce GTX 1060 6.0 GB",
#         "python_version": "3.13.9",
#         "torch_version": "2.8.0+cu126"
#     }
# }
