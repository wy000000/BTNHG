# %%
print("start import")
import time
time1 = time.time()
import sys
import os
# 获取当前文件所在目录的父目录
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeFeature.addressTimeFeatureClass import addressTimeFeatureClass
from EarlyStoppingClass import EarlyStoppingClass
from resultAnalysisClass import resultAnalysisClass
from ExtendedNNModule import ExtendedNNModule
from addressTimeDataClass import addressTimeDataClass
import torch
import torch.nn as nn
import datetime
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import importlib
time2 = time.time()
print("import used time: ", time2 - time1)
print(f"当前时间: {time.strftime('%m-%d %H:%M:%S', time.localtime())}")
# Out:
# start import
# import used time:  8.703169822692871
# 当前时间: 01-07 01:43:36

# %%
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
importlib.reload(sys.modules['BTNHGV2ParameterClass'])
importlib.reload(sys.modules['addressTimeDataClass'])
importlib.reload(sys.modules['addressTimeFeatureClass'])
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
addressTimeDataCls=addressTimeDataClass()

print(f"当前时间：{time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())}")
# Out:
# start read addressTimeData
# 读取耗时：0时0分0秒, addressTime_data_df.shape=(110935, 8)
# start process address time data
# 已完成20000行，进度18.03%
# 已完成40001行，进度36.06%
# 已完成60002行，进度54.09%
# 已完成80003行，进度72.12%
# 已完成100004行，进度90.15%
# 更新差异特征
# 时间特性处理完成。address_dict长度= 15218
# 时间特性处理耗时：0时0分16秒
# start build self.addressTimeFeature_dataSet
# 已完成2000行，进度13.14%
# 已完成4001行，进度26.29%
# 已完成6002行，进度39.44%
# 已完成8003行，进度52.59%
# 已完成10004行，进度65.74%
# 已完成12005行，进度78.89%
# 已完成14006行，进度92.04%
# build self.addressTimeFeature_dataSet used time: 0时0分10秒
# 当前时间：2026-01-07 02:20:59

# %%
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass

from ExtendedNNModule import ExtendedNNModule
from EarlyStoppingClass import EarlyStoppingClass
from DataSetModelTrainerTesterClass import DataSetModelTrainerTesterClass

from simple2DCNNClass import simple2DCNNClass

importlib.reload(sys.modules['BTNHGV2ParameterClass'])
importlib.reload(sys.modules['addressTimeDataClass'])
importlib.reload(sys.modules['addressTimeFeatureClass'])

importlib.reload(sys.modules['ExtendedNNModule'])
importlib.reload(sys.modules['EarlyStoppingClass'])
importlib.reload(sys.modules['DataSetModelTrainerTesterClass'])

importlib.reload(sys.modules['simple2DCNNClass'])

from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass

from ExtendedNNModule import ExtendedNNModule
from EarlyStoppingClass import EarlyStoppingClass
from DataSetModelTrainerTesterClass import DataSetModelTrainerTesterClass

from simple2DCNNClass import simple2DCNNClass

model=simple2DCNNClass(addressTimeDataCls=addressTimeDataCls)

TrainerTesterCls=DataSetModelTrainerTesterClass(model=model)

TrainerTesterCls.train_test()
# Out:
# using device: cuda
# start build trainLoader and testLoaser
# build trainLoader and testLoaser used time: 0时0分3秒
# 开始训练模型，使用设备: cuda
# Batch 0/96, Loss: 2.7137
# Batch 1/96, Loss: 5.0653
# Batch 2/96, Loss: 3.3887
# Batch 3/96, Loss: 3.2704
# Batch 4/96, Loss: 3.2031
# Batch 5/96, Loss: 2.8085
# Batch 6/96, Loss: 2.6713
# Batch 7/96, Loss: 2.7311
# Batch 8/96, Loss: 2.6581
# Batch 9/96, Loss: 2.6696
# Batch 10/96, Loss: 2.6531
# Batch 11/96, Loss: 2.6592
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 35
#      31 model=simple2DCNNClass(addressTimeDataCls=addressTimeDataCls)
#      33 TrainerTesterCls=DataSetModelTrainerTesterClass(model=model)
# ---> 35 TrainerTesterCls.train_test()
#
# File c:\Users\wy\source\repos\BTNHG\BTNHG\addressTimeFeature\DataSetModelTrainerTesterClass.py:59, in DataSetModelTrainerTesterClass.train_test(self, trainLoader, testLoader)
#      55 if trainLoader is None and testLoader is None:
#      56 	trainLoader, testLoader \
#      57 	= self._model.addressTimeDataCls.get_address_time_feature_trainLoader_testLoaser()
# ---> 59 self._train(trainLoader)
#      60 self._test(testLoader)
#      61 return
#
# File c:\Users\wy\source\repos\BTNHG\BTNHG\addressTimeFeature\DataSetModelTrainerTesterClass.py:83, in DataSetModelTrainerTesterClass._train(self, trainLoader)
#      78 # trainLoader, testLoader \
#      79 # 	= self._model.addressTimeDataCls.get_address_time_feature_trainLoader_testLoaser()
#      81 for epoch in range(1, self._epochs + 1):
#      82 	## 训练一个 epoch
# ---> 83 	loss, accuracy = self._train_one_epoch(trainLoader)
#      85 	stop=earlyStopping(loss, self._model, epoch)
#      87 	#epoch间隔显示
#
# File c:\Users\wy\source\repos\BTNHG\BTNHG\addressTimeFeature\DataSetModelTrainerTesterClass.py:151, in DataSetModelTrainerTesterClass._train_one_epoch(self, train_dataLoader)
#     148 self._optimizer.step()
#     150 # 统计损失和准确率
# --> 151 running_loss += loss.item()
#     152 _, predicted = outputs.max(1)
#     153 totalLables += labels.size(0)
#
# KeyboardInterrupt:
