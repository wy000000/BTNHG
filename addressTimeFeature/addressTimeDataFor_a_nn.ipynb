# %%
print("start import")
import time
time1 = time.time()
import sys
import os
# 获取当前文件所在目录的父目录
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeFeature.addressTimeFeatureClass import addressTimeFeatureClass
from EarlyStoppingClass import EarlyStoppingClass
from resultAnalysisClass import resultAnalysisClass
from ExtendedNNModule import ExtendedNNModule
from addressTimeDataClass import addressTimeDataClass
import torch
import torch.nn as nn
import datetime
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import importlib
time2 = time.time()
print("import used time: ", time2 - time1)
print(f"当前时间: {time.strftime('%m-%d %H:%M:%S', time.localtime())}")
# Out:
# start import
# import used time:  8.641626596450806
# 当前时间: 01-05 00:08:28

# %%
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
importlib.reload(sys.modules['BTNHGV2ParameterClass'])
importlib.reload(sys.modules['addressTimeDataClass'])
importlib.reload(sys.modules['addressTimeFeatureClass'])
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
addressTimeDataCls=addressTimeDataClass()

print(f"当前时间：{time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())}")
# Out:
# start read addressTimeData
# 读取完成。addressTime_data_df.shape= (110935, 8)
# start process address time data
# 已完成10000行，进度9.01%
# 已完成20001行，进度18.03%
# 已完成30002行，进度27.04%
# 已完成40003行，进度36.06%
# 已完成50004行，进度45.08%
# 已完成60005行，进度54.09%
# 已完成70006行，进度63.11%
# 已完成80007行，进度72.12%
# 已完成90008行，进度81.14%
# 已完成100009行，进度90.15%
# 已完成110010行，进度99.17%
# 更新差异特征
# 时间特性处理完成。address_dict长度= 15218
# 时间特性处理耗时：0时0分7秒
# start build TensorDataset
# 已完成2000行，进度13.14%
# 已完成4001行，进度26.29%
# 已完成6002行，进度39.44%
# 已完成8003行，进度52.59%
# 已完成10004行，进度65.74%
# 已完成12005行，进度78.89%
# 已完成14006行，进度92.04%
# build TensorDataset used time: 0时0分7秒
# start build trainLoader and testLoaser
# build trainLoader and testLoaser used time: 0时0分8秒
# start build KFold dataLoaders
# Processing fold 1/5
# Processing fold 2/5
# Processing fold 3/5
# Processing fold 4/5
# Processing fold 5/5
# build KFold dataLoaders used time: 0时1分8秒
# 当前时间：2026-01-05 00:14:05
