# %%
print("start import")
import time
time1 = time.time()
import sys
import os
# 获取当前文件所在目录的父目录
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeFeature.addressTimeFeatureClass import addressTimeFeatureClass
from EarlyStoppingClass import EarlyStoppingClass
from resultAnalysisClass import resultAnalysisClass
from ExtendedNNModule import ExtendedNNModule
from addressTimeDataClass import addressTimeDataClass
import torch
import torch.nn as nn
import datetime
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import importlib
time2 = time.time()
print("import used time: ", time2 - time1)
print(f"当前时间: {time.strftime('%m-%d %H:%M:%S', time.localtime())}")
# Out:
# start import
# import used time:  33.12067008018494
# 当前时间: 01-07 15:41:30

# %%
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
importlib.reload(sys.modules['BTNHGV2ParameterClass'])
importlib.reload(sys.modules['addressTimeDataClass'])
importlib.reload(sys.modules['addressTimeFeatureClass'])
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
addressTimeDataCls=addressTimeDataClass()

print(f"当前时间：{time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())}")
# Out:
# start read addressTimeData
# 读取耗时：0时0分0秒, addressTime_data_df.shape=(110935, 8)
# start process address time data
# 已完成20000行，进度18.03%
# 已完成40001行，进度36.06%
# 已完成60002行，进度54.09%
# 已完成80003行，进度72.12%
# 已完成100004行，进度90.15%
# 更新差异特征
# 时间特性处理完成。address_dict长度= 15218
# 时间特性处理耗时：0时0分6秒
# start build self.addressTimeFeature_dataSet
# 已完成2000行，进度13.14%
# 已完成4001行，进度26.29%
# 已完成6002行，进度39.44%
# 已完成8003行，进度52.59%
# 已完成10004行，进度65.74%
# 已完成12005行，进度78.89%
# 已完成14006行，进度92.04%
# build self.addressTimeFeature_dataSet used time: 0时0分6秒
# 当前时间：2026-01-07 15:42:12

# %%
from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
from ExtendedNNModule import ExtendedNNModule
from EarlyStoppingClass import EarlyStoppingClass
from DataSetModelTrainerTesterClass import DataSetModelTrainerTesterClass
from simple2DCNNClass import simple2DCNNClass
from resultAnalysisClass import resultAnalysisClass

importlib.reload(sys.modules['BTNHGV2ParameterClass'])
importlib.reload(sys.modules['addressTimeDataClass'])
importlib.reload(sys.modules['addressTimeFeatureClass'])
importlib.reload(sys.modules['ExtendedNNModule'])
importlib.reload(sys.modules['EarlyStoppingClass'])
importlib.reload(sys.modules['DataSetModelTrainerTesterClass'])
importlib.reload(sys.modules['simple2DCNNClass'])
importlib.reload(sys.modules['resultAnalysisClass'])

from BTNHGV2ParameterClass import BTNHGV2ParameterClass
from addressTimeDataClass import addressTimeDataClass
from addressTimeFeatureClass import addressTimeFeatureClass
from ExtendedNNModule import ExtendedNNModule
from EarlyStoppingClass import EarlyStoppingClass
from DataSetModelTrainerTesterClass import DataSetModelTrainerTesterClass
from simple2DCNNClass import simple2DCNNClass
from resultAnalysisClass import resultAnalysisClass

model=simple2DCNNClass(addressTimeDataCls=addressTimeDataCls)

TrainerTesterCls=DataSetModelTrainerTesterClass(model=model)

TrainerTesterCls.train_test()

resultCls=resultAnalysisClass(model)
resultCls.save()
# Out:
# using device: cuda
# start build trainLoader and testLoaser
# build trainLoader and testLoaser used time: 0时0分8秒
# 开始训练模型，使用设备: cuda
# simple2DCNNClass | Epoch   1 | loss: 2.5861 | accuracy: 11.7628 | best Loss: 2.5861 | patience:  0 | used time: 00:00:18
# Training completed, epoch : 1, loss: 2.5861, accuracy: 11.7628, used time: 00:00:18
# restore best model in epoch 1, best loss: 2.5861
# 当前时间: 01-07 15:42:56
# start test
# 测试用时: 0.756882905960083
# 当前时间: 01-07 15:42:56
# Evaluation metrics are computed.
# methodFolderPath=D:\BTNHG\BTNHGV2\result\simple2DCNNClass-2026.01.07 15.43.01-acc 0.2066
# BTNHGV2ParameterClass.txt已保存
# extendedAttributes.txt已保存
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\wy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File c:\Users\wy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 2 columns passed, passed data had 3 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 35
#      32 TrainerTesterCls.train_test()
#      34 resultCls=resultAnalysisClass(model)
# ---> 35 resultCls.save()
#
# File c:\Users\wy\source\repos\BTNHG\BTNHG\resultAnalysisClass.py:287, in resultAnalysisClass.save(self, save, saveModelStateDict, saveFullModel)
#     285 self._saveBTNHGV2ParameterClass()
#     286 self._saveExtendedAttributes()
# --> 287 self._save_epoch_loss_list()
#     288 self._saveY_true_preds_probs()
#     290 if(saveModelStateDict):
#
# File c:\Users\wy\source\repos\BTNHG\BTNHG\resultAnalysisClass.py:370, in resultAnalysisClass._save_epoch_loss_list(self)
#     367 	epoch_loss_list = self.model.epoch_loss_list
#     369 # 创建 DataFrame
# --> 370 df = pd.DataFrame(epoch_loss_list, columns=['Epoch', 'Loss'])
#     372 # 保存到 Excel，并生成散点图
#     373 with pd.ExcelWriter(filePath, engine="xlsxwriter") as writer:
#
# File c:\Users\wy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:855, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     853     if columns is not None:
#     854         columns = ensure_index(columns)
# --> 855     arrays, columns, index = nested_data_to_arrays(
#     856         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     857         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     858         data,
#     859         columns,
#     860         index,  # type: ignore[arg-type]
#     861         dtype,
#     862     )
#     863     mgr = arrays_to_mgr(
#     864         arrays,
#     865         columns,
#    (...)    868         typ=manager,
#     869     )
#     870 else:
#
# File c:\Users\wy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File c:\Users\wy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File c:\Users\wy\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 2 columns passed, passed data had 3 columns

# %%
from resultAnalysisClass import resultAnalysisClass
importlib.reload(sys.modules['resultAnalysisClass'])
from resultAnalysisClass import resultAnalysisClass

resultCls=resultAnalysisClass(model)
resultCls.save()
# Out:
# Evaluation metrics are computed.
# methodFolderPath=D:\BTNHG\BTNHGV2\result\simple2DCNNClass-2026.01.07 15.49.17-acc 0.2066
# BTNHGV2ParameterClass.txt已保存
# extendedAttributes.txt已保存
# 693 epoch_loss_list.xlsx已保存
# 745 y_true_preds_probs.xlsx已保存
# model.state_dict.pt已保存
